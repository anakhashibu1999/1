# %% [markdown]
# <a href="https://colab.research.google.com/github/anakhashibu1999/1/blob/main/Seaborn(Visualization)_tips.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#seaborn

# %%
import seaborn as sns
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(df.corr())

# %%
#joint plot

sns.jointplot(x='tip',y='total_bill',data=df)

# %%
sns.jointplot(x='tip',y='size',data=df)

# %%
sns.jointplot(x='tip',y='total_bill',data=df,kind='hex')

# %%
#or

sns.jointplot(x='total_bill',y='tip',data=df,kind='hex')

# %%
#pairplot

sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex')

# %%
sns.pairplot(df,hue='smoker')

# %%
sns.pairplot(df,hue='time')

# %%
sns.pairplot(df,hue='day')

# %% [markdown]
#  Distribution plot

# %%
sns.distplot(df['tip']) #density = %
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(df['tip'],kde=False)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#eg
x=[1,1,2,2,2,2,3,3,3,4,4]
import matplotlib.pyplot as plt
plt.hist(x)
plt.show()

# %%
sns.distplot(df['tip'],kde=False,bins=5)

# %%
#eg

10,12,13,14,15,16,17,19,34,23,43,24
#bin1=10-15 = 5
#bin2=16-30 = 3....
# Out:
# (10, 12, 13, 14, 15, 16, 17, 19, 34, 23, 43, 24)

# %%
sns.distplot(df['tip'],kde=False,bins=3)

# %% [markdown]
# **countplot**

# %%
sns.countplot('sex',data=df)

#more is male
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.countplot(y='sex',data=df)

# %%
sns.countplot('smoker',data=df)

# %%
sns.countplot('time',data=df)

# %%
sns.countplot('day',data=df)

# %%
sns.countplot(y='day',data=df)

# %%
sns.countplot('smoker',data=df,hue='sex')

# %%
sns.countplot('smoker',data=df,hue='time')

# %%
sns.countplot('time',data=df,hue='smoker')

# %% [markdown]
# **Boxplot**

# %%
sns.boxplot('smoker','total_bill',data=df)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#1 2 3 4 6 5 7 9 8

#asc= 1 2 3 4 5 6 7 8 9
#median= 
#percentile
#interquartile range

# %% [markdown]
# **violinplot**

# %% [markdown]
# ****

# %%
sns.violinplot('total_bill','day',data=df)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
